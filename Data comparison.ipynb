# %% [markdown]
# ### COMPARISONS

# %% [markdown]
# ### ONLINE REDPITAYA SIGNAL GENERATOR VERSES THE RECORD ON SIGLENT SDS 1102A

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data= pd.read_csv("comparison.csv")

# %%
data ## note that the values are in MHz
# Out:
#     Online Gen  Siglent Scope
# 0            1          0.912
# 1            5          4.565
# 2           10          9.129
# 3           15         13.693
# 4           20         18.258
# 5           25         22.822
# 6           30         27.387
# 7           35         31.951
# 8           40         36.516
# 9           45         41.081
# 10          50         43.001
# 11          55         38.639
# 12          60         41.015

# %%
data.describe()
# Out:
#        Online Gen  Siglent Scope
# count   13.000000      13.000000
# mean    30.076923      25.305308
# std     19.345376      14.827660
# min      1.000000       0.912000
# 25%     15.000000      13.693000
# 50%     30.000000      27.387000
# 75%     45.000000      38.639000
# max     60.000000      43.001000

# %%
plt.plot(data["Siglent Scope"],data["Online Gen"])
plt.show()

# %%
sns.histplot(data=data)
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(data=data)
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
